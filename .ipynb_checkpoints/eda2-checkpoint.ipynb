# %%
import re
import numpy as np
import seaborn as sns
import os
import pandas as pd
import sklearn as sk
from sklearn import svm
from sklearn.neural_network import MLPClassifier
import matplotlib.pyplot as plt

# %%
print(os.listdir(), '\n', os.getcwd())

with open('plot_time.csv', 'r') as init_data:
    raw_data = pd.read_csv(init_data)
# Out:
# ['.git', '.gitattributes', '.ipynb_checkpoints', 'big_MCI_plot.png', 'data_analysis_script.py', 'DX_bl_big_MCI_plot.png', 'EDA.ipynb', 'eda2.ipynb', 'plot_time.csv', 'prelim data analysis.py', 'PTGENDER_big_MCI_plot.png', 'simple_data.csv', 'TADPOLE_D1_D2.csv', 'TADPOLE_D1_D2.py', 'TADPOLE_D1_D2_Dict.csv', 'TADPOLE_D2.m', 'TADPOLE_D3.csv', 'TADPOLE_D3.m', 'TADPOLE_readme.txt']
#  C:\Users\work_cbdvl\Documents\GitHub\Project-daybreak

# %%
patients = raw_data.loc[:,"RID"].unique()

changers = np.zeros(len(patients))
impaired = np.zeros(len(patients))

cata = pd.DataFrame(patients)
cata["change"] = changers
cata["impaired"] = impaired
cata.rename(columns={0:"RID"}, inplace=True)

for i,v in enumerate(cata.loc[:,"RID"]):
    vals = raw_data.loc[raw_data["RID"] == v, ["DX_bl", "DXCHANGE"]]
    if sum(vals.DXCHANGE > 3) > 0:
        cata.loc[i, "change"] = 1
    if ((vals.DX_bl.any() != "CN") | sum(vals.DXCHANGE > 1) > 0):
        cata.loc[i, "impaired"] = 1

# %% [markdown]
# loop = raw_data.copy()
# loop["change"] = np.zeros(len(raw_data))
# loop["impaired"] = np.zeros(len(raw_data))
# for i in patients:
#     loop.loc[loop["RID"] == i, "change"] = cata.loc[cata["RID"] == i, "change"].mean()
#     loop.loc[loop["RID"] == i, "impaired"] = cata.loc[cata["RID"] == i, "impaired"].mean()
# loop.describe()

# %%
merge = pd.merge(raw_data, cata, on="RID", how="outer")
merge.describe()
# Out:
#          Unnamed: 0           RID           AGE      PTEDUCAT         APOE4  \
# count  12741.000000  12741.000000  12741.000000  12741.000000  12729.000000
# mean    6370.000000   2240.325720     73.814865     15.988384      0.537277
# std     3678.154225   1855.269911      6.973068      2.829707      0.655835
# min        0.000000      2.000000     54.400000      4.000000      0.000000
# 25%     3185.000000    618.000000     69.600000     14.000000      0.000000
# 50%     6370.000000   1280.000000     73.800000     16.000000      0.000000
# 75%     9555.000000   4328.000000     78.700000     18.000000      1.000000
# max    12740.000000   5296.000000     91.400000     20.000000      2.000000
#
#            CDRSB_bl     ADAS11_bl     ADAS13_bl       MMSE_bl  \
# count  12741.000000  12724.000000  12663.000000  12741.000000
# mean       1.355820      9.814569     15.505631     27.566910
# std        1.554823      5.908569      8.713772      2.394201
# min        0.000000      0.000000      0.000000     18.000000
# 25%        0.000000      5.670000      9.000000     26.000000
# 50%        1.000000      8.670000     14.000000     28.000000
# 75%        2.000000     13.000000     20.330000     29.000000
# max       10.000000     42.670000     54.670000     30.000000
#
#        RAVLT_immediate_bl  ...   Entorhinal       MidTemp          FDG  \
# count        12705.000000  ...  6469.000000   6469.000000  3352.000000
# mean            36.452499  ...  3444.718813  19203.260318     1.208239
# std             12.046854  ...   811.771966   3138.155124     0.160831
# min              0.000000  ...  1041.000000   8044.000000     0.636804
# 25%             28.000000  ...  2905.000000  17183.000000     1.109723
# 50%             35.000000  ...  3482.000000  19240.000000     1.219805
# 75%             45.000000  ...  4013.000000  21397.000000     1.314253
# max             71.000000  ...  6711.000000  32189.000000     1.753320
#
#               AV45  ABETA_UPENNBIOMK9_04_19_17  TAU_UPENNBIOMK9_04_19_17  \
# count  2118.000000                 2371.000000               2371.000000
# mean      1.194780                 1023.744285                293.062876
# std       0.227518                  597.445735                132.260409
# min       0.835796                  100.000000                 40.000000
# 25%       1.010035                  572.150000                202.600000
# 50%       1.113975                  832.000000                264.400000
# 75%       1.362275                 1375.500000                356.500000
# max       2.669210                 3592.000000               1500.000000
#
#        PTAU_UPENNBIOMK9_04_19_17       VISNUMS        change      impaired
# count                2370.000000  12741.000000  12741.000000  12741.000000
# mean                   28.068156     25.859901      0.351071      0.783063
# std                    14.569570     25.945824      0.477324      0.412176
# min                     4.000000      0.000000      0.000000      0.000000
# 25%                    17.797500      6.000000      0.000000      1.000000
# 50%                    24.470000     18.000000      0.000000      1.000000
# 75%                    34.397500     36.000000      1.000000      1.000000
# max                   150.000000    120.000000      1.000000      1.000000
#
# [8 rows x 41 columns]

# %%
merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12741 entries, 0 to 12740
# Data columns (total 49 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  12741 non-null  int64
#  1   RID                         12741 non-null  int64
#  2   EXAMDATE                    12741 non-null  object
#  3   DX_bl                       12741 non-null  object
#  4   AGE                         12741 non-null  float64
#  5   PTGENDER                    12741 non-null  object
#  6   PTEDUCAT                    12741 non-null  int64
#  7   PTETHCAT                    12741 non-null  object
#  8   PTRACCAT                    12741 non-null  object
#  9   PTMARRY                     12741 non-null  object
#  10  APOE4                       12729 non-null  float64
#  11  EXAMDATE_bl                 12741 non-null  object
#  12  CDRSB_bl                    12741 non-null  float64
#  13  ADAS11_bl                   12724 non-null  float64
#  14  ADAS13_bl                   12663 non-null  float64
#  15  MMSE_bl                     12741 non-null  int64
#  16  RAVLT_immediate_bl          12705 non-null  float64
#  17  RAVLT_learning_bl           12705 non-null  float64
#  18  RAVLT_forgetting_bl         12705 non-null  float64
#  19  RAVLT_perc_forgetting_bl    12684 non-null  float64
#  20  FAQ_bl                      12696 non-null  float64
#  21  Ventricles_bl               12251 non-null  float64
#  22  Hippocampus_bl              10960 non-null  float64
#  23  WholeBrain_bl               12492 non-null  float64
#  24  Entorhinal_bl               10847 non-null  float64
#  25  Fusiform_bl                 10847 non-null  float64
#  26  MidTemp_bl                  10847 non-null  float64
#  27  ICV_bl                      12647 non-null  float64
#  28  Years_bl                    12741 non-null  float64
#  29  Month_bl                    12741 non-null  float64
#  30  Month                       12741 non-null  int64
#  31  M                           12741 non-null  int64
#  32  DX                          8904 non-null   object
#  33  DXCHANGE                    8892 non-null   float64
#  34  CDRSB                       8963 non-null   float64
#  35  MMSE                        8932 non-null   float64
#  36  RAVLT_immediate             8831 non-null   float64
#  37  Hippocampus                 6802 non-null   float64
#  38  WholeBrain                  7689 non-null   float64
#  39  Entorhinal                  6469 non-null   float64
#  40  MidTemp                     6469 non-null   float64
#  41  FDG                         3352 non-null   float64
#  42  AV45                        2118 non-null   float64
#  43  ABETA_UPENNBIOMK9_04_19_17  2371 non-null   float64
#  44  TAU_UPENNBIOMK9_04_19_17    2371 non-null   float64
#  45  PTAU_UPENNBIOMK9_04_19_17   2370 non-null   float64
#  46  VISNUMS                     12741 non-null  int64
#  47  change                      12741 non-null  float64
#  48  impaired                    12741 non-null  float64
# dtypes: float64(34), int64(7), object(8)
# memory usage: 4.9+ MB

# %%
merge.PTGENDER.unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
merge.loc[merge["PTGENDER"] == "Male", "PTGENDER"] = 1
merge.loc[merge["PTGENDER"] == "Female", "PTGENDER"] = 0
merge.PTGENDER = merge.PTGENDER.astype("category")

# %%
merge.PTGENDER.unique()
# Out:
# [1, 0]
# Categories (2, int64): [1, 0]

# %%
plot_cols = merge.select_dtypes(include ="number")
sns.heatmap(plot_cols.corr())

# %%
# Out:
#        Unnamed: 0   RID   AGE  PTEDUCAT  APOE4  CDRSB_bl  ADAS11_bl  \
# 0               0     2  74.3        16    0.0       0.0      10.67
# 1            5723     2  74.3        16    0.0       0.0      10.67
# 2            5724     2  74.3        16    0.0       0.0      10.67
# 3            5725     2  74.3        16    0.0       0.0      10.67
# 4            5726     2  74.3        16    0.0       0.0      10.67
# ...           ...   ...   ...       ...    ...       ...        ...
# 12736       10802  5295  75.5        15    1.0       0.5      11.00
# 12737       10803  5295  75.5        15    1.0       0.5      11.00
# 12738       12277  5295  75.5        15    1.0       0.5      11.00
# 12739       10804  5296  69.3        14    0.0       0.0       9.00
# 12740       12302  5296  69.3        14    0.0       0.0       9.00
#
#        ADAS13_bl  MMSE_bl  RAVLT_immediate_bl  ...  Entorhinal  MidTemp  \
# 0          18.67       28                44.0  ...      4177.0  27936.0
# 1          18.67       28                44.0  ...         NaN      NaN
# 2          18.67       28                44.0  ...         NaN      NaN
# 3          18.67       28                44.0  ...         NaN      NaN
# 4          18.67       28                44.0  ...         NaN      NaN
# ...          ...      ...                 ...  ...         ...      ...
# 12736      18.00       29                28.0  ...         NaN      NaN
# 12737      18.00       29                28.0  ...         NaN      NaN
# 12738      18.00       29                28.0  ...         NaN      NaN
# 12739      14.00       29                38.0  ...      4701.0  32189.0
# 12740      14.00       29                38.0  ...         NaN      NaN
#
#            FDG     AV45  ABETA_UPENNBIOMK9_04_19_17  TAU_UPENNBIOMK9_04_19_17  \
# 0      1.36926      NaN                         NaN                       NaN
# 1      1.21655      NaN                         NaN                       NaN
# 2          NaN      NaN                         NaN                       NaN
# 3          NaN      NaN                         NaN                       NaN
# 4          NaN      NaN                         NaN                       NaN
# ...        ...      ...                         ...                       ...
# 12736  1.16317  1.31903                       416.8                     88.69
# 12737      NaN      NaN                         NaN                       NaN
# 12738      NaN  1.27419                         NaN                       NaN
# 12739  1.42926  1.13838                      1460.0                    224.90
# 12740      NaN  1.28309                         NaN                       NaN
#
#        PTAU_UPENNBIOMK9_04_19_17  VISNUMS  change  impaired
# 0                            NaN        0     1.0       1.0
# 1                            NaN        6     1.0       1.0
# 2                            NaN       36     1.0       1.0
# 3                            NaN       60     1.0       1.0
# 4                            NaN       66     1.0       1.0
# ...                          ...      ...     ...       ...
# 12736                       8.53        0     0.0       1.0
# 12737                        NaN        3     0.0       1.0
# 12738                        NaN       24     0.0       1.0
# 12739                      20.90        0     0.0       1.0
# 12740                        NaN       24     0.0       1.0
#
# [12741 rows x 41 columns]
