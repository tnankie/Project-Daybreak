# %% [markdown]
# import potentially helpful modules and libraries
# may not use them all

# %%
import re
import numpy as np
import seaborn as sns
import os 
import pandas as pd
import sklearn as sk
from sklearn import svm
from sklearn.neural_network import MLPClassifier
import matplotlib.pyplot as plt

# %% [markdown]
# find the files and check the directory, if all good then load the data

# %%
print(os.listdir(), '\n', os.getcwd())

with open('plot_time.csv', 'r') as init_data:
    raw_data = pd.read_csv(init_data)
# Out:
# ['.git', '.gitattributes', '.ipynb_checkpoints', 'data_analysis_script.py', 'plot_time.csv', 'prelim data analysis.py', 'simple_data.csv', 'TADPOLE_D1_D2.csv', 'TADPOLE_D1_D2.py', 'TADPOLE_D1_D2_Dict.csv', 'TADPOLE_D2.m', 'TADPOLE_D3.csv', 'TADPOLE_D3.m', 'TADPOLE_readme.txt', 'Untitled.ipynb']
#  C:\Users\tnank\Documents\GitHub\Project-daybreak

# %%
print(raw_data.columns)
# Out:
# Index(['Unnamed: 0', 'RID', 'EXAMDATE', 'DX_bl', 'AGE', 'PTGENDER', 'PTEDUCAT',
#        'PTETHCAT', 'PTRACCAT', 'PTMARRY', 'APOE4', 'EXAMDATE_bl', 'CDRSB_bl',
#        'ADAS11_bl', 'ADAS13_bl', 'MMSE_bl', 'RAVLT_immediate_bl',
#        'RAVLT_learning_bl', 'RAVLT_forgetting_bl', 'RAVLT_perc_forgetting_bl',
#        'FAQ_bl', 'Ventricles_bl', 'Hippocampus_bl', 'WholeBrain_bl',
#        'Entorhinal_bl', 'Fusiform_bl', 'MidTemp_bl', 'ICV_bl', 'Years_bl',
#        'Month_bl', 'Month', 'M', 'DX', 'DXCHANGE', 'CDRSB', 'MMSE',
#        'RAVLT_immediate', 'Hippocampus', 'WholeBrain', 'Entorhinal', 'MidTemp',
#        'FDG', 'AV45', 'ABETA_UPENNBIOMK9_04_19_17', 'TAU_UPENNBIOMK9_04_19_17',
#        'PTAU_UPENNBIOMK9_04_19_17', 'VISNUMS'],
#       dtype='object')

# %%
for c,v in enumerate(raw_data.columns):
    print(c, v )
# Out:
# 0 Unnamed: 0
# 1 RID
# 2 EXAMDATE
# 3 DX_bl
# 4 AGE
# 5 PTGENDER
# 6 PTEDUCAT
# 7 PTETHCAT
# 8 PTRACCAT
# 9 PTMARRY
# 10 APOE4
# 11 EXAMDATE_bl
# 12 CDRSB_bl
# 13 ADAS11_bl
# 14 ADAS13_bl
# 15 MMSE_bl
# 16 RAVLT_immediate_bl
# 17 RAVLT_learning_bl
# 18 RAVLT_forgetting_bl
# 19 RAVLT_perc_forgetting_bl
# 20 FAQ_bl
# 21 Ventricles_bl
# 22 Hippocampus_bl
# 23 WholeBrain_bl
# 24 Entorhinal_bl
# 25 Fusiform_bl
# 26 MidTemp_bl
# 27 ICV_bl
# 28 Years_bl
# 29 Month_bl
# 30 Month
# 31 M
# 32 DX
# 33 DXCHANGE
# 34 CDRSB
# 35 MMSE
# 36 RAVLT_immediate
# 37 Hippocampus
# 38 WholeBrain
# 39 Entorhinal
# 40 MidTemp
# 41 FDG
# 42 AV45
# 43 ABETA_UPENNBIOMK9_04_19_17
# 44 TAU_UPENNBIOMK9_04_19_17
# 45 PTAU_UPENNBIOMK9_04_19_17
# 46 VISNUMS

# %% [markdown]
# is there a connection between gender and cognitive degeneration?

# %%
gender_plot = sns.pairplot(raw_data.iloc[:,[4,5,6,7,8,9,22,37,43]], hue = 'PTGENDER', diag_kind = 'auto')

# %% [markdown]
# There may be a slight difference in years of education between male and female and also a slightly larger hipocampus size. Hippocampus size is likely due to overal size difference in genders, need to check if hipocampus size is absolute size or relative size. (And if there is typically a gender difference in hipocampus  relative size.)
# Education need to perform a t test to see if the difference is statistically significan't and then keep in mind if it need to be corrected for in assessing male-female differences.
#
# how about race and cognitive outcome?

# %%
race_plot = sns.pairplot(raw_data.iloc[:,[4,5,6,7,8,9,22,37,43]], hue = 'PTRACCAT', diag_kind='auto')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Hard to say if there is much of a race effect.
# how about ethnicity?

# %%
eth_plot = sns.pairplot(raw_data.iloc[:,[4,5,6,7,8,9,22,37,43]], hue = 'PTETHCAT', diag_kind='auto')

# %% [markdown]
# again no clear differece between latino/non-latino
# what about marital status?

# %%
marital_plot = sns.pairplot(raw_data.iloc[:,[4,5,6,7,8,9,22,37,43]], hue = 'PTMARRY', diag_kind='auto')

# %% [markdown]
# unknown marital status tend to be younger while widowed tend to be older, no difference between married, never married and divorced
