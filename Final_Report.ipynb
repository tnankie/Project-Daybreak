# %%
import pandas as pd
import os 
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv("./data/plot_time_2.csv")
df.head()
# Out:
#    Unnamed: 0  RID    EXAMDATE DX_bl  DXCHANGE   AGE PTGENDER  PTEDUCAT  \
# 0           0    2  2005-09-08    CN     1.000  74.3     Male        16
# 1        5723    2  2006-03-06    CN     1.000  74.3     Male        16
# 2        5724    2  2008-08-27    CN     1.000  74.3     Male        16
# 3        5725    2  2010-09-22    CN     1.000  74.3     Male        16
# 4        5726    2  2011-03-04    CN     1.375  74.3     Male        16
#
#           PTETHCAT PTRACCAT  ...  Years_bl  Month_bl  Month   M   DX  AV45  \
# 0  Not Hisp/Latino    White  ...  0.000000   0.00000      0   0   NL   NaN
# 1  Not Hisp/Latino    White  ...  0.490075   5.86885      6   6   NL   NaN
# 2  Not Hisp/Latino    White  ...  2.967830  35.54100     36  36   NL   NaN
# 3  Not Hisp/Latino    White  ...  5.037650  60.32790     60  60   NL   NaN
# 4  Not Hisp/Latino    White  ...  5.483920  65.67210     66  66  NaN   NaN
#
#    ABETA_UPENNBIOMK9_04_19_17  TAU_UPENNBIOMK9_04_19_17  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12741 entries, 0 to 12740
# Data columns (total 56 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  12741 non-null  int64
#  1   RID                         12741 non-null  int64
#  2   EXAMDATE                    12741 non-null  object
#  3   DX_bl                       12741 non-null  object
#  4   DXCHANGE                    12734 non-null  float64
#  5   AGE                         12741 non-null  float64
#  6   PTGENDER                    12741 non-null  object
#  7   PTEDUCAT                    12741 non-null  int64
#  8   PTETHCAT                    12741 non-null  object
#  9   PTRACCAT                    12741 non-null  object
#  10  PTMARRY                     12741 non-null  object
#  11  APOE4                       12729 non-null  float64
#  12  FDG                         10623 non-null  float64
# ...

# %%
df1 = df.dropna()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1373 entries, 111 to 12739
# Data columns (total 56 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  1373 non-null   int64
#  1   RID                         1373 non-null   int64
#  2   EXAMDATE                    1373 non-null   object
#  3   DX_bl                       1373 non-null   object
#  4   DXCHANGE                    1373 non-null   float64
#  5   AGE                         1373 non-null   float64
#  6   PTGENDER                    1373 non-null   object
#  7   PTEDUCAT                    1373 non-null   int64
#  8   PTETHCAT                    1373 non-null   object
#  9   PTRACCAT                    1373 non-null   object
#  10  PTMARRY                     1373 non-null   object
#  11  APOE4                       1373 non-null   float64
#  12  FDG                         1373 non-null   float64
# ...

# %%
cor_df = df.corr()
cor_df
# Out:
#                             Unnamed: 0       RID  DXCHANGE       AGE  \
# Unnamed: 0                    1.000000  0.412502  0.052475 -0.032022
# RID                           0.412502  1.000000 -0.017280 -0.168435
# DXCHANGE                      0.052475 -0.017280  1.000000 -0.025452
# AGE                          -0.032022 -0.168435 -0.025452  1.000000
# PTEDUCAT                      0.026358  0.075849 -0.072355 -0.062089
# APOE4                        -0.017111  0.027369  0.261941 -0.136502
# FDG                           0.072798  0.116078 -0.363035 -0.129980
# CDRSB                         0.075260 -0.065664  0.561280  0.059040
# ADAS11                        0.015280 -0.060250  0.511714  0.079859
# ADAS13                        0.004710 -0.073764  0.546350  0.104896
# MMSE                         -0.025800  0.064013 -0.504001 -0.061380
# RAVLT_immediate               0.036233  0.097079 -0.495600 -0.170573
# RAVLT_learning               -0.000147  0.077537 -0.423098 -0.098758
# ...

# %%
df3 = df.copy()
check = pd.get_dummies(df3, columns = ["DX"])
check.shape
# Out:
# (12741, 63)

# %%
check.corr()
# Out:
#                             Unnamed: 0       RID  DXCHANGE       AGE  \
# Unnamed: 0                    1.000000  0.412502  0.052475 -0.032022
# RID                           0.412502  1.000000 -0.017280 -0.168435
# DXCHANGE                      0.052475 -0.017280  1.000000 -0.025452
# AGE                          -0.032022 -0.168435 -0.025452  1.000000
# PTEDUCAT                      0.026358  0.075849 -0.072355 -0.062089
# APOE4                        -0.017111  0.027369  0.261941 -0.136502
# FDG                           0.072798  0.116078 -0.363035 -0.129980
# CDRSB                         0.075260 -0.065664  0.561280  0.059040
# ADAS11                        0.015280 -0.060250  0.511714  0.079859
# ADAS13                        0.004710 -0.073764  0.546350  0.104896
# MMSE                         -0.025800  0.064013 -0.504001 -0.061380
# RAVLT_immediate               0.036233  0.097079 -0.495600 -0.170573
# RAVLT_learning               -0.000147  0.077537 -0.423098 -0.098758
# ...

# %%
df2 = df.copy()
df2["cat_dx"] = df2["DX"].astype("category")
df2["num_dx"] = df2.cat_dx.cat.codes
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12741 entries, 0 to 12740
# Data columns (total 58 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  12741 non-null  int64
#  1   RID                         12741 non-null  int64
#  2   EXAMDATE                    12741 non-null  object
#  3   DX_bl                       12741 non-null  object
#  4   DXCHANGE                    12734 non-null  float64
#  5   AGE                         12741 non-null  float64
#  6   PTGENDER                    12741 non-null  object
#  7   PTEDUCAT                    12741 non-null  int64
#  8   PTETHCAT                    12741 non-null  object
#  9   PTRACCAT                    12741 non-null  object
#  10  PTMARRY                     12741 non-null  object
#  11  APOE4                       12729 non-null  float64
#  12  FDG                         10623 non-null  float64
# ...

# %%
df2_corr = df2.corr()
sb.histplot(x="num_dx", data=df2_corr, bins = 10)
# Out:
# <AxesSubplot:xlabel='num_dx', ylabel='Count'>

# %%
df_train = df2_corr.loc[(df2_corr.num_dx > 0.2) | (df2_corr.num_dx < -0.2), :]
tran = df_train.T
cols = list(tran.columns)
# Out:
# ['Unnamed: 0', 'DXCHANGE', 'FDG', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate', 'RAVLT_learning', 'RAVLT_perc_forgetting', 'FAQ', 'Hippocampus', 'Entorhinal', 'CDRSB_bl', 'ADAS11_bl', 'ADAS13_bl', 'MMSE_bl', 'RAVLT_immediate_bl', 'RAVLT_learning_bl', 'RAVLT_perc_forgetting_bl', 'FAQ_bl', 'Hippocampus_bl', 'ABETA_UPENNBIOMK9_04_19_17', 'TAU_UPENNBIOMK9_04_19_17', 'PTAU_UPENNBIOMK9_04_19_17', 'num_dx']

# %%
training = df2.loc[:,cols].copy()

# %%
training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12741 entries, 0 to 12740
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  12741 non-null  int64
#  1   DXCHANGE                    12734 non-null  float64
#  2   FDG                         10623 non-null  float64
#  3   CDRSB                       12741 non-null  float64
#  4   ADAS11                      12738 non-null  float64
#  5   ADAS13                      12738 non-null  float64
#  6   MMSE                        12741 non-null  float64
#  7   RAVLT_immediate             12732 non-null  float64
#  8   RAVLT_learning              12732 non-null  float64
#  9   RAVLT_perc_forgetting       12718 non-null  float64
#  10  FAQ                         12733 non-null  float64
#  11  Hippocampus                 12472 non-null  float64
#  12  Entorhinal                  12249 non-null  float64
# ...

# %%
training.iloc[:,0].unique
# Out:
# <bound method Series.unique of 0            0
# 1         5723
# 2         5724
# 3         5725
# 4         5726
#          ...
# 12736    10802
# 12737    10803
# 12738    12277
# 12739    10804
# 12740    12302
# Name: Unnamed: 0, Length: 12741, dtype: int64>
